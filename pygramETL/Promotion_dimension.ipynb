# %%
import pyodbc
import pygrametl

# Update these with your actual SSMS details
STAGING_CONNECTION_STRING = (
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=DESKTOP-AR905LJ;"
    "Database=staging;"
    "UID=sa;"
    "PWD=ghom3220;"
)
DWH_CONNECTION_STRING = ( 
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=DESKTOP-AR905LJ;"
    "Database=DWH;"
    "UID=sa;"
    "PWD=ghom3220;"
)

# %%
source_conn = pyodbc.connect(STAGING_CONNECTION_STRING)
source_connection = pygrametl.ConnectionWrapper(source_conn)
source_cursor = source_connection.cursor()
source_cursor.execute("SELECT @@version;")
result = source_cursor.fetchone()
print(f"connected to {result[0]}!")
# Out:
# connected to Microsoft SQL Server 2025 (RTM) - 17.0.1000.7 (X64)
# 	Oct 21 2025 12:05:57
# 	Copyright (C) 2025 Microsoft Corporation
# 	Standard Developer Edition (64-bit) on Windows 10 Pro 10.0 <X64> (Build 26200: ) (Hypervisor)
# !

# %%
dwh_conn = pyodbc.connect(DWH_CONNECTION_STRING)
dwh_connection = pygrametl.ConnectionWrapper(dwh_conn)
dwh_cursor = dwh_connection.cursor()
dwh_cursor.execute("SELECT @@version;")
result = dwh_cursor.fetchone()
print(f"connected to {result[0]}!")
dwh_connection.setasdefault()
# Out:
# connected to Microsoft SQL Server 2025 (RTM) - 17.0.1000.7 (X64)
# 	Oct 21 2025 12:05:57
# 	Copyright (C) 2025 Microsoft Corporation
# 	Standard Developer Edition (64-bit) on Windows 10 Pro 10.0 <X64> (Build 26200: ) (Hypervisor)
# !

# %%
create_table_sql = """
IF NOT EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[Dim_Promotion]') AND type in (N'U'))
BEGIN
    CREATE TABLE Dim_Promotion (
        PromotionID INT Primary Key,
        CodePromotion VARCHAR(50),
    );
END
"""
dwh_cursor.execute(create_table_sql)
dwh_connection.commit()

# %%
from pygrametl.tables import Dimension
Dim_Promotion = pygrametl.tables.Dimension(
    name='Dim_Promotion',
    key='PromotionID',
    attributes=['CodePromotion']
)

# %%
promotion_source=source_cursor.execute("SELECT Distinct CodePromo FROM source")
for row in promotion_source:
    promotion_data = {
        "CodePromotion": row.CodePromo
    }
    print(promotion_data)
    Dim_Promotion.ensure(promotion_data)
dwh_connection.commit()
dwh_cursor.close()
dwh_connection.close()
# Out:
# {'CodePromotion': 'PROMO94'}
# {'CodePromotion': 'PROMO46'}
# {'CodePromotion': 'PROMO30'}
# {'CodePromotion': 'PROMO83'}
# {'CodePromotion': 'PROMO14'}
# {'CodePromotion': 'PROMO96'}
# {'CodePromotion': 'PROMO53'}
# {'CodePromotion': 'PROMO56'}
# {'CodePromotion': 'PROMO93'}
# {'CodePromotion': 'PROMO32'}
# {'CodePromotion': 'PROMO60'}
# {'CodePromotion': 'PROMO86'}
# {'CodePromotion': 'PROMO10'}
# {'CodePromotion': 'PROMO20'}
# {'CodePromotion': 'PROMO44'}
# {'CodePromotion': 'PROMO43'}
# {'CodePromotion': 'PROMO62'}
# {'CodePromotion': 'PROMO73'}
# {'CodePromotion': 'PROMO74'}
# {'CodePromotion': 'PROMO87'}
# {'CodePromotion': 'PROMO58'}
# {'CodePromotion': 'PROMO89'}
# {'CodePromotion': 'PROMO72'}
# {'CodePromotion': 'PROMO91'}
# {'CodePromotion': 'PROMO55'}
# {'CodePromotion': 'PROMO41'}
# {'CodePromotion': 'PROMO88'}
# {'CodePromotion': None}
# {'CodePromotion': 'PROMO95'}
# {'CodePromotion': 'PROMO97'}
# {'CodePromotion': 'PROMO81'}
# {'CodePromotion': 'PROMO70'}
# {'CodePromotion': 'PROMO45'}
# {'CodePromotion': 'PROMO59'}
# {'CodePromotion': 'PROMO48'}
# {'CodePromotion': 'PROMO57'}
# {'CodePromotion': 'PROMO39'}
# {'CodePromotion': 'PROMO98'}
# {'CodePromotion': 'PROMO47'}
# {'CodePromotion': 'PROMO49'}
# {'CodePromotion': 'PROMO85'}
# {'CodePromotion': 'PROMO69'}
# {'CodePromotion': 'PROMO22'}
# {'CodePromotion': 'PROMO51'}
# {'CodePromotion': 'PROMO12'}
# {'CodePromotion': 'PROMO38'}
# {'CodePromotion': 'PROMO82'}
# {'CodePromotion': 'PROMO79'}
# {'CodePromotion': 'PROMO61'}
# {'CodePromotion': 'PROMO11'}
# {'CodePromotion': 'PROMO21'}
# {'CodePromotion': 'PROMO35'}
# {'CodePromotion': 'PROMO65'}
# {'CodePromotion': 'PROMO15'}
# {'CodePromotion': 'PROMO67'}
# {'CodePromotion': 'PROMO25'}
# {'CodePromotion': 'PROMO52'}
# {'CodePromotion': 'PROMO28'}
# {'CodePromotion': 'PROMO37'}
# {'CodePromotion': 'PROMO77'}
# {'CodePromotion': 'PROMO68'}
# {'CodePromotion': 'PROMO42'}
# {'CodePromotion': 'PROMO18'}
# {'CodePromotion': 'PROMO99'}
# {'CodePromotion': 'PROMO27'}
# {'CodePromotion': 'PROMO31'}
# {'CodePromotion': 'PROMO17'}
# {'CodePromotion': 'PROMO29'}
# {'CodePromotion': 'PROMO19'}
# {'CodePromotion': 'PROMO64'}
# {'CodePromotion': 'PROMO26'}
# {'CodePromotion': 'PROMO50'}
# {'CodePromotion': 'PROMO76'}
# {'CodePromotion': 'PROMO24'}
# {'CodePromotion': 'PROMO16'}
# {'CodePromotion': 'PROMO71'}
# {'CodePromotion': 'PROMO33'}
# {'CodePromotion': 'PROMO34'}
# {'CodePromotion': 'PROMO80'}
# {'CodePromotion': 'PROMO66'}
# {'CodePromotion': 'PROMO54'}
# {'CodePromotion': 'PROMO63'}
# {'CodePromotion': 'PROMO78'}
# {'CodePromotion': 'PROMO84'}
# {'CodePromotion': 'PROMO23'}
# {'CodePromotion': 'PROMO36'}
# {'CodePromotion': 'PROMO13'}
# {'CodePromotion': 'PROMO75'}
# {'CodePromotion': 'PROMO40'}
# {'CodePromotion': 'PROMO90'}
# {'CodePromotion': 'PROMO92'}
